# %%
# Importando as bibliotecas

import pandas as pd 
import numpy as np
import os
from datetime import datetime, date
from google.cloud import bigquery
from dotenv import load_dotenv
import pyarrow


# Carregando variáveis de ambiente
load_dotenv()
# Out:
# True

# %%
# Imprtando dados de 2015_01

df_2015_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2015-01.csv", sep=';')

# %%
# Imprtando dados de 2015_02

df_2015_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2015-02.csv", sep=';')

# %%
# Unindo os dois df
df_2015 =  pd.concat((df_2015_01, df_2015_02))

# %%
df_2015.head()
# Out:
#   Regiao - Sigla Estado - Sigla         Municipio  \
# 0              N             AC  SENADOR GUIOMARD
# 1              N             AC  SENADOR GUIOMARD
# 2              N             AC  SENADOR GUIOMARD
# 3              N             AC  SENADOR GUIOMARD
# 4              N             AC  SENADOR GUIOMARD
#
#                        Revenda      CNPJ da Revenda             Nome da Rua  \
# 0  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 1  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 2  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 3  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 4      AUTO POSTO QUINARI LTDA   10.209.732/0001-40  AVENIDA CASTELO BRANCO
#
#   Numero Rua Complemento   Bairro        Cep     Produto Data da Coleta  \
# 0        122         NaN  TRIUNFO  69925-000    GASOLINA     01/01/2015
# 1        122         NaN  TRIUNFO  69925-000      ETANOL     01/01/2015
# 2        122         NaN  TRIUNFO  69925-000      DIESEL     01/01/2015
# 3        122         NaN  TRIUNFO  69925-000  DIESEL S10     01/01/2015
# 4       2709         NaN   CENTRO  69925-000    GASOLINA     01/01/2015
#
#   Valor de Venda Valor de Compra Unidade de Medida Bandeira
# 0           3,44             NaN        R$ / litro      DNP
# 1              3             NaN        R$ / litro      DNP
# 2            3,1             NaN        R$ / litro      DNP
# 3            3,2             NaN        R$ / litro      DNP
# 4           3,44           2,784        R$ / litro    SABBÁ

# %%
df_2015.tail()
# Out:
#        Regiao - Sigla Estado - Sigla    Municipio                 Revenda  \
# 410969             SE             MG  SETE LAGOAS   POSTO PETROLAGOS LTDA
# 410970             SE             MG  SETE LAGOAS   POSTO PETROLAGOS LTDA
# 410971              N             AC   RIO BRANCO  POSTO ALTO ALEGRE LTDA
# 410972              N             AC   RIO BRANCO  POSTO ALTO ALEGRE LTDA
# 410973              N             AC   RIO BRANCO  POSTO ALTO ALEGRE LTDA
#
#             CNPJ da Revenda     Nome da Rua Numero Rua Complemento  \
# 410969   19.863.856/0001-19  RODOVIA MG-424          0     KM: 04;
# 410970   19.863.856/0001-19  RODOVIA MG-424          0     KM: 04;
# 410971   20.420.950/0001-82   RODOVIA AC 10       1321         NaN
# 410972   20.420.950/0001-82   RODOVIA AC 10       1321         NaN
# 410973   20.420.950/0001-82   RODOVIA AC 10       1321         NaN
#
#              Bairro        Cep     Produto Data da Coleta Valor de Venda  \
# 410969   ESMERALDAS  35702-098      DIESEL     28/12/2015          2,799
# 410970   ESMERALDAS  35702-098  DIESEL S10     28/12/2015          2,999
# 410971  ALTO ALEGRE  69914-720    GASOLINA     30/12/2015           3,92
# 410972  ALTO ALEGRE  69914-720      ETANOL     30/12/2015           3,18
# 410973  ALTO ALEGRE  69914-720      DIESEL     30/12/2015           3,48
#
#        Valor de Compra Unidade de Medida                      Bandeira
# 410969          2,6316        R$ / litro                        ALESAT
# 410970          2,7802        R$ / litro                        ALESAT
# 410971          3,5053        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 410972          2,5234        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 410973          3,1009        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.

# %%
df_2015_pe = df_2015[df_2015["Estado - Sigla"] == "PE"]

# %%
df_2015_pe
# Out:
#        Regiao - Sigla Estado - Sigla                Municipio  \
# 270                NE             PE                   LAJEDO
# 271                NE             PE                   LAJEDO
# 272                NE             PE                   LAJEDO
# 273                NE             PE                   LAJEDO
# 274                NE             PE                   LAJEDO
# ...               ...            ...                      ...
# 410927             NE             PE  JABOATAO DOS GUARARAPES
# 410963             NE             PE                   LAJEDO
# 410964             NE             PE                   LAJEDO
# 410965             NE             PE                   LAJEDO
# 410966             NE             PE                   LAJEDO
#
#                                               Revenda      CNPJ da Revenda  \
# 270                             JM COMBUSTIVEIS LTDA.   09.273.777/0001-02
# 271                             JM COMBUSTIVEIS LTDA.   09.273.777/0001-02
# 272                             JM COMBUSTIVEIS LTDA.   09.273.777/0001-02
# 273                 I. DE MEDEIROS SALES COMBUSTIVEIS   07.620.681/0001-30
# 274                 I. DE MEDEIROS SALES COMBUSTIVEIS   07.620.681/0001-30
# ...                                               ...                  ...
# 410927  ROCHA & CARNEIRO COMBUSTIVEIS E SERVICOS LTDA   18.311.003/0001-01
# 410963                        OASIS COMBUSTIVEIS LTDA   17.322.859/0001-10
# 410964                        OASIS COMBUSTIVEIS LTDA   17.322.859/0001-10
# 410965                        OASIS COMBUSTIVEIS LTDA   17.322.859/0001-10
# 410966                        OASIS COMBUSTIVEIS LTDA   17.322.859/0001-10
#
#                                     Nome da Rua Numero Rua Complemento  \
# 270     AVENIDA PRESIDENTE JUSCELINO KUBITSCHEK        S/N         NaN
# 271     AVENIDA PRESIDENTE JUSCELINO KUBITSCHEK        S/N         NaN
# 272     AVENIDA PRESIDENTE JUSCELINO KUBITSCHEK        S/N         NaN
# 273     AVENIDA PRESIDENTE JUSCELINO KUBITSCHEC        990         NaN
# 274     AVENIDA PRESIDENTE JUSCELINO KUBITSCHEC        990         NaN
# ...                                         ...        ...         ...
# 410927                      RUA BARAO DE MORENO          7         NaN
# 410963                     RUA PERPETUO SOCORRO        149         NaN
# 410964                     RUA PERPETUO SOCORRO        149         NaN
# 410965                     RUA PERPETUO SOCORRO        149         NaN
# 410966                     RUA PERPETUO SOCORRO        149         NaN
#
#            Bairro        Cep     Produto Data da Coleta Valor de Venda  \
# 270        CENTRO  55385-000    GASOLINA     01/01/2015          2,989
# 271        CENTRO  55385-000      ETANOL     01/01/2015          2,289
# 272        CENTRO  55385-000      DIESEL     01/01/2015          2,489
# 273        CENTRO  55385-000    GASOLINA     01/01/2015          2,989
# 274        CENTRO  55385-000      ETANOL     01/01/2015          2,359
# ...           ...        ...         ...            ...            ...
# 410927  VILA RICA  54100-680  DIESEL S10     29/12/2015          3,049
# 410963     CENTRO  55385-000    GASOLINA     29/12/2015          3,599
# 410964     CENTRO  55385-000      ETANOL     29/12/2015          2,999
# 410965     CENTRO  55385-000      DIESEL     29/12/2015          2,899
# 410966     CENTRO  55385-000  DIESEL S10     29/12/2015          2,999
#
#        Valor de Compra Unidade de Medida             Bandeira
# 270              2,527        R$ / litro               BRANCA
# 271                NaN        R$ / litro               BRANCA
# 272               2,29        R$ / litro               BRANCA
# 273                NaN        R$ / litro               BRANCA
# 274                NaN        R$ / litro               BRANCA
# ...                ...               ...                  ...
# 410927             NaN        R$ / litro  SETTA DISTRIBUIDORA
# 410963             NaN        R$ / litro             IPIRANGA
# 410964             NaN        R$ / litro             IPIRANGA
# 410965             NaN        R$ / litro             IPIRANGA
# 410966             NaN        R$ / litro             IPIRANGA
#
# [39970 rows x 16 columns]

# %%
# Configurando credenciais

# Caminho do arquivo de credenciais GCP
credencial = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

# Identificador do projeto no GCP
project_id = os.getenv("PROJECT_ID")

# Tabela Bronze no BigQuery
table_id = os.getenv("BRONZE_2015")

# Inicialização do cliente BigQuery

# Define a variavel de ambiente
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credencial

# Cria o cliente Bigquery ao projeto configurado
client = bigquery.Client(project=project_id)

# %%
# Criação e carga da Tabela BRONZE

# Configuração do job de carga no BigQuery
# WRITE_TRUNCATE garante que a tabela Bronze seja sempre sobrescrita,
# mantendo apenas o retrato mais recente dos dados de origem
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE"
)

# Envia o DataFrame para o BigQuery,
# criando a tabela automaticamente caso ainda não exista
job = client.load_table_from_dataframe(
    df_2015_pe,
    table_id,
    job_config=job_config
)

# Aguarda a finalização do job para garantir consistência da carga
job.result()

# Confirmação visual de sucesso da operação
print("✅ Tabela Bronze criada e dados carregados com sucesso")
# Out:
# /home/danielpedro/anaconda3/envs/combustivel_projeto/lib/python3.11/site-packages/google/cloud/bigquery/_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# ✅ Tabela Bronze criada e dados carregados com sucesso
