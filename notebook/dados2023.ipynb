# %%
import pandas as pd

# %%
df_2023_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/Preços semestrais - AUTOMOTIVOS_2023.01.csv", sep=';')

# %%
df_2023_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/Preços semestrais - AUTOMOTIVOS_2023.02.csv", sep=';')

# %%
df_2023 = pd.concat((df_2023_01, df_2023_02))

# %%
df_2023.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 904000 entries, 0 to 472423
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     904000 non-null  str
#  1   Estado - Sigla     904000 non-null  str
#  2   Municipio          904000 non-null  str
#  3   Revenda            904000 non-null  str
#  4   CNPJ da Revenda    904000 non-null  str
#  5   Nome da Rua        904000 non-null  str
#  6   Numero Rua         903753 non-null  str
#  7   Complemento        208421 non-null  str
#  8   Bairro             902318 non-null  str
#  9   Cep                904000 non-null  str
#  10  Produto            904000 non-null  str
#  11  Data da Coleta     904000 non-null  str
#  12  Valor de Venda     904000 non-null  str
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  904000 non-null  str
#  15  Bandeira           904000 non-null  str
# dtypes: float64(1), str(15)
# memory usage: 117.2 MB
