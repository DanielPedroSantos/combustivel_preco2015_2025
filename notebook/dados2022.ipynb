# %%
import pandas as pd

# %%
df_2022_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/precos-semestrais-ca-2022-01.csv", sep=";")

# %%
df_2022_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2022-02.csv", sep=";")

# %%
df_2022 = pd.concat((df_2022_01,df_2022_02))

# %%
df_2022.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 907502 entries, 0 to 378077
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     907502 non-null  str
#  1   Estado - Sigla     907502 non-null  str
#  2   Municipio          907502 non-null  str
#  3   Revenda            907502 non-null  str
#  4   CNPJ da Revenda    907502 non-null  str
#  5   Nome da Rua        907502 non-null  str
#  6   Numero Rua         907113 non-null  str
#  7   Complemento        195200 non-null  str
#  8   Bairro             905168 non-null  str
#  9   Cep                907502 non-null  str
#  10  Produto            907502 non-null  str
#  11  Data da Coleta     907502 non-null  str
#  12  Valor de Venda     907502 non-null  str
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  907502 non-null  str
#  15  Bandeira           907502 non-null  str
# dtypes: float64(1), str(15)
# memory usage: 117.7 MB
