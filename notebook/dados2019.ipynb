# %%
import pandas as pd

# %%
df_2019_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2019-01.csv", sep=";")

# %%
df_2019_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP  GUARULHOS
# 4              S             RS     CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 2  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# ...

# %%
df_2019_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2019-02.csv", sep=";")

# %%
df_2019_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0              S             RS    CANOAS
# 1              S             RS    CANOAS
# 2              S             RS    CANOAS
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                        Revenda      CNPJ da Revenda  \
# 0  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 1  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 2  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 3    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#                 Nome da Rua Numero Rua  Complemento       Bairro        Cep  \
# 0  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# 1  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# ...

# %%
df_2019 = pd.concat((df_2019_01, df_2019_02))

# %%
df_2019.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1004029 entries, 0 to 507298
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Regiao - Sigla     1004029 non-null  str
#  1   Estado - Sigla     1004029 non-null  str
#  2   Municipio          1004029 non-null  str
#  3   Revenda            1004029 non-null  str
#  4   CNPJ da Revenda    1004029 non-null  str
#  5   Nome da Rua        1004029 non-null  str
#  6   Numero Rua         1003417 non-null  str
#  7   Complemento        261785 non-null   str
#  8   Bairro             1000240 non-null  str
#  9   Cep                1004029 non-null  str
#  10  Produto            1004029 non-null  str
#  11  Data da Coleta     1004029 non-null  str
#  12  Valor de Venda     1004029 non-null  str
#  13  Valor de Compra    381869 non-null   str
#  14  Unidade de Medida  1004029 non-null  str
#  15  Bandeira           1004029 non-null  str
# dtypes: str(16)
# ...
