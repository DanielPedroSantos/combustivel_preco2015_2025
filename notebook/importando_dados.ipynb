# %%
import pandas as pd

# %%
# Imprtando dados de 2015_01

df_2015_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2015-01.csv", sep=';')

# %%
df_2015_01.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 696774 entries, 0 to 696773
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     696774 non-null  str
#  1   Estado - Sigla     696774 non-null  str
#  2   Municipio          696774 non-null  str
#  3   Revenda            696774 non-null  str
#  4   CNPJ da Revenda    696774 non-null  str
#  5   Nome da Rua        696774 non-null  str
#  6   Numero Rua         696341 non-null  str
#  7   Complemento        181073 non-null  str
#  8   Bairro             694242 non-null  str
#  9   Cep                696774 non-null  str
#  10  Produto            696774 non-null  str
#  11  Data da Coleta     696774 non-null  str
#  12  Valor de Venda     696774 non-null  str
#  13  Valor de Compra    266617 non-null  str
#  14  Unidade de Medida  696774 non-null  str
#  15  Bandeira           696774 non-null  str
# dtypes: str(16)
# memory usage: 85.1 MB

# %%
df_2015_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla         Municipio  \
# 0              N             AC  SENADOR GUIOMARD
# 1              N             AC  SENADOR GUIOMARD
# 2              N             AC  SENADOR GUIOMARD
# 3              N             AC  SENADOR GUIOMARD
# 4              N             AC  SENADOR GUIOMARD
#
#                        Revenda      CNPJ da Revenda             Nome da Rua  \
# 0  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 1  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 2  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 3  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 4      AUTO POSTO QUINARI LTDA   10.209.732/0001-40  AVENIDA CASTELO BRANCO
#
#   Numero Rua Complemento   Bairro        Cep     Produto Data da Coleta  \
# 0        122         NaN  TRIUNFO  69925-000    GASOLINA     01/01/2015
# ...

# %%
# Imprtando dados de 2015_02

df_2015_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2015-02.csv", sep=';')

# %%
df_2015_02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 410974 entries, 0 to 410973
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     410974 non-null  str
#  1   Estado - Sigla     410974 non-null  str
#  2   Municipio          410974 non-null  str
#  3   Revenda            410974 non-null  str
#  4   CNPJ da Revenda    410974 non-null  str
#  5   Nome da Rua        410974 non-null  str
#  6   Numero Rua         410697 non-null  str
#  7   Complemento        104189 non-null  str
#  8   Bairro             409723 non-null  str
#  9   Cep                410974 non-null  str
#  10  Produto            410974 non-null  str
#  11  Data da Coleta     410974 non-null  str
#  12  Valor de Venda     410974 non-null  str
#  13  Valor de Compra    164426 non-null  str
#  14  Unidade de Medida  410974 non-null  str
#  15  Bandeira           410974 non-null  str
# dtypes: str(16)
# memory usage: 50.2 MB

# %%
df_2015_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla    Municipio                       Revenda  \
# 0             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 1             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 2             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 3             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 4              S             PR  PATO BRANCO          SANTOS & MERLO LTDA.
#
#        CNPJ da Revenda        Nome da Rua Numero Rua Complemento  Bairro  \
# 0   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 1   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 2   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 3   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 4   79.854.667/0001-01      RUA TOCANTINS       2535         NaN  CENTRO
#
#          Cep     Produto Data da Coleta Valor de Venda Valor de Compra  \
# ...

# %%
# Importando dados de 2016/01
df_2016_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2016-01.csv", sep=';')

# %%
df_2016_01.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 486897 entries, 0 to 486896
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     486897 non-null  str
#  1   Estado - Sigla     486897 non-null  str
#  2   Municipio          486897 non-null  str
#  3   Revenda            486897 non-null  str
#  4   CNPJ da Revenda    486897 non-null  str
#  5   Nome da Rua        486897 non-null  str
#  6   Numero Rua         486619 non-null  str
#  7   Complemento        124413 non-null  str
#  8   Bairro             485102 non-null  str
#  9   Cep                486897 non-null  str
#  10  Produto            486897 non-null  str
#  11  Data da Coleta     486897 non-null  str
#  12  Valor de Venda     486897 non-null  str
#  13  Valor de Compra    191504 non-null  str
#  14  Unidade de Medida  486897 non-null  str
#  15  Bandeira           486897 non-null  str
# dtypes: str(16)
# memory usage: 59.4 MB

# %%
df_2016_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#               Nome da Rua Numero Rua  Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
# Importando
