# %%
import pandas as pd

# %%
df_2018_01 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2018-01.csv", sep=";")

# %%
df_2018_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             NE             BA  SALVADOR
# 1             NE             BA  SALVADOR
# 2             NE             BA  SALVADOR
# 3             NE             BA  SALVADOR
# 4              S             RS    CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 1                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 2                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 3                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua Complemento  Bairro        Cep  \
# 0         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 1         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 2         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 3         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 4  AVENIDA GUILHERME SCHELL       6340         NaN  CENTRO  92310-000
#
#       Produto Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0         GNV     02/01/2018           2,37          1,7383           R$ / m³
# 1  DIESEL S10     02/01/2018           3,24          3,1366        R$ / litro
# 2      ETANOL     02/01/2018           2,93          2,6194        R$ / litro
# 3    GASOLINA     02/01/2018           3,62          3,6017        R$ / litro
# 4         GNV     02/01/2018          2,699             NaN           R$ / m³
#
#                        Bandeira
# 0  PETROBRAS DISTRIBUIDORA S.A.
# 1  PETROBRAS DISTRIBUIDORA S.A.
# 2  PETROBRAS DISTRIBUIDORA S.A.
# 3  PETROBRAS DISTRIBUIDORA S.A.
# 4                        BRANCA

# %%
df_2018_02 = pd.read_csv("/home/danielpedro/Engenharia de Dados/combustivel_preco2015_2025/dataset/ca-2018-02.csv", sep=";")

# %%
df_2018 =  pd.concat((df_2018_01, df_2018_02,))

# %%
df_2018.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 963002 entries, 0 to 493168
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     963002 non-null  str
#  1   Estado - Sigla     963002 non-null  str
#  2   Municipio          963002 non-null  str
#  3   Revenda            963002 non-null  str
#  4   CNPJ da Revenda    963002 non-null  str
#  5   Nome da Rua        963002 non-null  str
#  6   Numero Rua         962208 non-null  str
#  7   Complemento        250596 non-null  str
#  8   Bairro             960044 non-null  str
#  9   Cep                963002 non-null  str
#  10  Produto            963002 non-null  str
#  11  Data da Coleta     963002 non-null  str
#  12  Valor de Venda     963002 non-null  str
#  13  Valor de Compra    386490 non-null  str
#  14  Unidade de Medida  963002 non-null  str
#  15  Bandeira           963002 non-null  str
# dtypes: str(16)
# memory usage: 124.9 MB
